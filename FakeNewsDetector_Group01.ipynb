# %%
import pandas as pd
import numpy as np
import re

# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import porter
nltk.download('punkt')
nltk.download('stopwords')
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/danielstephensen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/danielstephensen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Task 1

# %% [markdown]
# Group members: Angelina Näsström (nzv947), Daniel Stephensen (fbp131), Kristina Wilke (mlt790), Lauritz Koch (hdg618)

# %% [markdown]
# ## Task 2

# %% [markdown]
# We have used the following procedures: cleaning, tokenizing, removing stopwords and stemming the data. When cleaning the data we made sure of the following:
# 1. all letters are in lowercase
# 2. all urls are written as < URL >
# 3. all dates are written as < DATE >
# 4. all emails are written as < EMAIL >
# 5. all numbers are written as < NUM >
# 6. all unimportant symbols are removed
#
# Converting all letters to lowercase makes it easier to compare different words. Point 2-5 are useful because it makes it possible to count the number of urls, dates, emails and numbers. Also, removing these makes sure that they are not treated as words. Removing unimportant symbols makes sure that these are not treated as words.
#
# Tokenizing all words
#
# Removing stopwords is useful because these words do not help giving meaning to the documents, in other words they are noise.
#
# Stemming the data is useful because it makes sure that different variants of the same word is converted into the rood of the word. This way it is easier to

# %%
data = pd.read_csv('news_sample.csv')

# %%
def cleantext(text):
    text = str(text)
    text = text.lower()
    text = re.sub(r'<|>', "", text)
    text = re.sub(r'(https?:\/\/)?w{0,3}\.?[a-z]+\.[a-z]\w*[\w\/-]*', "<URL>", text)
    text = re.sub(r'(jan\.?(uary)?|feb\.?(uary)?|mar\.?(ch)?|apr\.?(il)?|may|jun\.(e)?|jul\.(y)?|aug\.?(ust)?|sep\.?(tember)?|oct\.?(ober)?|nov\.?(ember)?|dec\.?(ember)?|monday|tuesday|wednesday|thursday|friday|saturday|sunday) (the )?\d{1,2}((th)?,?( \d{4})?)?', "<DATE>", text)
    text = re.sub(r'\w+@\w+\.[a-zA-Z]{2,3}', "<EMAIL>", text)
    text = re.sub(r'[0-9]+', "<NUM>", text)
    text = re.sub(r'(\\n)+|\s{2,}|(\\t+)', " ", text)
    text = re.sub(r'\.|,|\\|-|\?|\(|\)|\||&|"|”|“|:|!|\+|-|–|—|\/|\$|%|€|#|;|\[|\]|©|®|…', "", text)
    return text

clean_data = [cleantext(i) for i in data["content"]]
string_of_contents = " ".join(clean_data)

# %%
#Below should be replaced with actual data from after Cleaning
cleaned_data_SAMPLE_FOR_CODING_PURPOSES = string_of_contents

#Create tokens based on clean_data. cl = clean, da = data
clda_tokens = word_tokenize(cleaned_data_SAMPLE_FOR_CODING_PURPOSES)

#print((clda_tokens))

# %%
#StopWordsCLeanDAta_tokens
stop_words = stopwords.words('english')
swclda_tokens = [word for word in clda_tokens if not word in stop_words]

# %%
stemmer = porter.PorterStemmer()
stemmed_tokens = [stemmer.stem(token) for token in swclda_tokens]

#create Stemmed StopWorded vocab
stsw_vocab = set(stemmed_tokens)
stsw_vocab.remove('<')
stsw_vocab.remove('>')
print(stsw_vocab)
# Out:
# {'pullback', 'balliol', 'progressrisk', 'suffici', 'broaden', 'reestablish', 'lifetim', 'freshli', 'lifeblood', 'bubbl', 'unedit', 'pave', 'parenthood', 'jn', 'pimlott', 'uniti', 'explod', 'kirkuk', 'sport', 'thencandid', 'countryhermann', 'challengesand', 'imageri', 'narendra', 'seligman', 'outbreak', 'cunningham', 'tour', 'gauntlet', 'adenau', 'fargo', 'mba', 'bacon', 'area', 'armysometh', 'contenti', 'besid', 'disastr', 'unfriendli', 'netherland', 'embarrass', 'bitter', 'facebook', 'sixti', 'nearzero', 'neonazi', 'bakan', 'liabil', 'ordinair', 'alp', 'behalf', 'moneymak', 'shaleoil', 'feedback', 'contractor', 'godsend', 'belhaj', 'belong', 'reneg', 'martyr', 'ahmm', 'psalm', 'halt', 'jashua', 'biodiesel', 'gallant', 'lawbreak', 'vix', 'specialforc', 'atlántida', 'uphold', 'engag', 'least', 'niceti', 'kaaz', 'joel', 'rush', 'malcolm', 'lawsuit', 'commemor', 'bolshevik', 'buffett', 'asia', 'sabbat', 'radic', 'tpipsec', 'irrespons', 'hotel', 'slaveprostitutecal', 'def', 'user', 'evangelist', 'cmd=_sxclickhosted_button_id=gjtktzyvyfcn', 'scientist', 'octogenarian', 'persist', 'alcohol', 'loc', 'retreat', 'judiciari', 'prorussian', 'microanalyz', 'blockchain', 'eerili', 'misunderstand', 'inhibit', 'deal', 'siren', 'dearborn', 'anomali', 'kissing', 'reli', 'imposit', 'osteoporosi', 'clearli', 'holist', 'cruz', 'reorganis', 'crunch', 'koch', 'transnat', 'estuarin', 'shortsight', 'ampl', 'pentagon', 'strzok', 'showcas', 'opium', 'caus', 'vega', 'pronunci', 'offens', 'barclay', 'tad', 'offici', 'proposit', 'rahmbo', 'p', 'nhc', 'grain', 'fece', 'elit', 'sandi', 'macroanalysi', 'wicca', 'excret', 'slavefactori', 'uncertainti', 'notwithstand', 'assum', 'valley', 'wall', 'longer', 'factcheck', 'homan', 'destin', 'behaviour', 'empir', 'whale', 'dual', 'furthermor', 'cheapest', 'landmin', 'led', 'philosoph', 'reiter', 'drone', 'busili', 'franklin', 'clerk', 'unschedul', 'tpv', 'continuum', 'secretari', 'viabl', 'rapidlymov', 'best', 'epicent', 'necessit', 'alberta', 'discipl', 'paunchi', 'demonet', 'incred', 'goingon', 'gravest', 'perpetu', 'signific', 'satisfi', 'numer', 'count', 'methionin', 'overhead', 'train', 'prowestern', 'sadli', 'pinko', 'eclect', 'maninterpret', 'post', 'frieden', 'darwin', 'gari', 'usmilitari', 'central', 'backseat', 'chronic', 'scar', 'gov', 'edg', 'artifici', 'loudest', 'bet', 'autocatalyst', 'airstrik', 'omega', 'spokesperson', 'brief', 'eec', 'toilet', 'knowledg', 'strength', 'drunk', 'beauti', 'card', 'underprivileg', 'seiryomaru', 'gasolin', 'impact', 'bottom', 'utter', 'beamer', 'soontob', 'centralis', 'guru', 'river', 'nail', 'sustainableagricultur', 'embolden', 'ushow', 'problemat', 'diagnosi', 'victim', 'chock', 'governor', 'five', 'legaci', 'excel', 'shah', 'congressmen', 'nowfam', 'motivationwhi', 'tall', 'circuit', 'reduct', 'accomplish', 'wellwat', 'shore', 'fender', 'mich', 'dress', 'countermeasur', 'unfett', 'insid', 'cw', 'secondhom', 'costeffect', 'viacom', 'listeria', 'believ', 'intelligentsia', 'lockstep', 'predic', 'riser', 'multilay', 'poverti', 'quit', 'punter', 'socgen', 'session', 'headwind', 'prescrib', 'interpret', 'pursu', 'heaven', 'assault', 'trait', 'nowadult', 'brown', 'nonprofit', 'hematolog', 'chao', 'univ', 'carol', 'hi', 'ff', 'buri', 'emot', 'crusad', 'insult', 'suleman', 'gene', 'transperson', 'permian', 'incorrectconvict', 'pinch', 'util', 'laura', 'cnn', 'afraid', 'z', 'capita', 'dogfish', 'undergo', 'coral', 'encourag', 'sugar', 'nutritionist', 'lund', 'stockholm', 'dehsimah', 'justin', 'ufo', 'modi', 'toss', 'foment', 'hickam', 'beli', 'indonesian', 'monopoli', 'lawabid', 'cap', 'intrins', 'axi', 'droid', 'surpris', 'europ', 'expel', 'pregnant', 'allev', 'turkey', 'handcuff', 'ordin', 'handler', '*', 'ripe', 'chard', 'extend', 'detain', 'mow', 'antisemit', 'gestur', 'northeast', 'widelyheard', 'faux', 'axcel', 'odyssey', 'nauert', 'untouch', 'ottawa', 'transcendent', 'baez', 'byron', 'salafi', 'garza', 'mindmuscl', 'milo', 'bungl', 'depreci', 'worth', 'index', 'transito ...
